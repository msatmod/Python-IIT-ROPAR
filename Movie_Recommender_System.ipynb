# %% [markdown]
# #Project
#
# ##Movie Recommender System
#
# A pandas based movie recommender system to recommend good or bad movies.

# %%
#import libraries
import pandas as pd
import numpy as np

# %%
#load the dataset
movies_df = pd.read_csv('datasets/IMDB-Movie-Data.csv', index_col='Title')
movies_df.head()
# Out:
#                          Rank  ... Metascore
# Title                          ...
# Guardians of the Galaxy     1  ...      76.0
# Prometheus                  2  ...      65.0
# Split                       3  ...      62.0
# Sing                        4  ...      59.0
# Suicide Squad               5  ...      40.0
#
# [5 rows x 11 columns]

# %%
movies_df.tail()
# Out:
#                         Rank  ... Metascore
# Title                         ...
# Secret in Their Eyes     996  ...      45.0
# Hostel: Part II          997  ...      46.0
# Step Up 2: The Streets   998  ...      50.0
# Search Party             999  ...      22.0
# Nine Lives              1000  ...      11.0
#
# [5 rows x 11 columns]

# %%
#shape of dataset
movies_df.shape
# Out:
# (1000, 11)

# %%
#get information about dataset
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 93.8+ KB

# %%
#duplicate entries
temp_df = movies_df.append(movies_df)
temp_df.shape
# Out:
# (2000, 11)

# %%
#drop duplicate
temp_df = temp_df.drop_duplicates()
temp_df.shape
# Out:
# (1000, 11)

# %%
temp_new_df = temp_df.append(temp_df)
temp_new_df.shape
# Out:
# (2000, 11)

# %%
temp_new_df.drop_duplicates(inplace=True)
temp_new_df.shape
# Out:
# (1000, 11)

# %% [markdown]
# ##Syntax
#
# drop_duplicates(keep=[first,last,false])
#
# first: (default) Drops duplicates except for the first occurence
#
# last: Drops duplicates except for the last occurence
#
# false: Drops all duplicates

# %%
temp_new_df = temp_df.append(temp_df)
temp_new_df.drop_duplicates(inplace=True,keep=False)
temp_new_df.shape
# Out:
# (0, 11)

# %%
#columns of dataset
movies_df.columns
# Out:
# Index(['Rank', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
#renaming a particular column
movies_df.rename(columns={'Runtime (Minutes)':'Runtime', 'Revenue (Millions)':'Revenue'}, inplace=True)
movies_df.columns
# Out:
# Index(['Rank', 'Genre', 'Description', 'Director', 'Actors', 'Year', 'Runtime',
#        'Rating', 'Votes', 'Revenue', 'Metascore'],
#       dtype='object')

# %%
#renaming all the column names with lower case
movies_df.columns = [col.lower() for col in movies_df]
movies_df.columns
# Out:
# Index(['rank', 'genre', 'description', 'director', 'actors', 'year', 'runtime',
#        'rating', 'votes', 'revenue', 'metascore'],
#       dtype='object')

# %%
#calculate null values 
movies_df.isnull()
# Out:
#                           rank  genre  description  ...  votes  revenue  metascore
# Title                                               ...
# Guardians of the Galaxy  False  False        False  ...  False    False      False
# Prometheus               False  False        False  ...  False    False      False
# Split                    False  False        False  ...  False    False      False
# Sing                     False  False        False  ...  False    False      False
# Suicide Squad            False  False        False  ...  False    False      False
# ...                        ...    ...          ...  ...    ...      ...        ...
# Secret in Their Eyes     False  False        False  ...  False     True      False
# Hostel: Part II          False  False        False  ...  False    False      False
# Step Up 2: The Streets   False  False        False  ...  False    False      False
# Search Party             False  False        False  ...  False     True      False
# Nine Lives               False  False        False  ...  False    False      False
#
# [1000 rows x 11 columns]

# %%
#total number of null values
movies_df.isnull().sum()
# Out:
# rank             0
# genre            0
# description      0
# director         0
# actors           0
# year             0
# runtime          0
# rating           0
# votes            0
# revenue        128
# metascore       64
# dtype: int64

# %%
#removing null values
rev = movies_df['revenue']
rev.head()
# Out:
# Title
# Guardians of the Galaxy    333.13
# Prometheus                 126.46
# Split                      138.12
# Sing                       270.32
# Suicide Squad              325.02
# Name: revenue, dtype: float64

# %%
#mean
rev_mean = rev.mean()
rev_mean
# Out:
# 82.95637614678897

# %%
movies_df.isnull().sum()
# Out:
# rank             0
# genre            0
# description      0
# director         0
# actors           0
# year             0
# runtime          0
# rating           0
# votes            0
# revenue        128
# metascore       64
# dtype: int64

# %%
meta = movies_df['metascore']
meta_mean = meta.mean()
meta_mean
meta.fillna(meta_mean, inplace=True)
movies_df.isnull().sum()
# Out:
# rank             0
# genre            0
# description      0
# director         0
# actors           0
# year             0
# runtime          0
# rating           0
# votes            0
# revenue        128
# metascore        0
# dtype: int64

# %%
movies_df.describe()
# Out:
#               rank         year  ...     revenue    metascore
# count  1000.000000  1000.000000  ...  872.000000  1000.000000
# mean    500.500000  2012.783000  ...   82.956376    58.985043
# std     288.819436     3.205962  ...  103.253540    16.634858
# min       1.000000  2006.000000  ...    0.000000    11.000000
# 25%     250.750000  2010.000000  ...   13.270000    47.750000
# 50%     500.500000  2014.000000  ...   47.985000    58.985043
# 75%     750.250000  2016.000000  ...  113.715000    71.000000
# max    1000.000000  2016.000000  ...  936.630000   100.000000
#
# [8 rows x 7 columns]

# %%
movies_df['genre'].describe()
# Out:
# count                        1000
# unique                        207
# top       Action,Adventure,Sci-Fi
# freq                           50
# Name: genre, dtype: object

# %% [markdown]
# ####DataFrames slicing, selecting, extracting

# %%
genre_col = movies_df['genre']
type(genre_col)
# Out:
# pandas.core.series.Series

# %%
genre_col = movies_df[['genre']]
type(genre_col)
# Out:
# pandas.core.frame.DataFrame

# %%
gen_rate = movies_df[['genre','rating']]
gen_rate
# Out:
#                                             genre  rating
# Title
# Guardians of the Galaxy   Action,Adventure,Sci-Fi     8.1
# Prometheus               Adventure,Mystery,Sci-Fi     7.0
# Split                             Horror,Thriller     7.3
# Sing                      Animation,Comedy,Family     7.2
# Suicide Squad            Action,Adventure,Fantasy     6.2
# ...                                           ...     ...
# Secret in Their Eyes          Crime,Drama,Mystery     6.2
# Hostel: Part II                            Horror     5.5
# Step Up 2: The Streets        Drama,Music,Romance     6.2
# Search Party                     Adventure,Comedy     5.6
# Nine Lives                  Comedy,Family,Fantasy     5.3
#
# [1000 rows x 2 columns]

# %% [markdown]
# by rows
#
#
# .loc: locates the value by name
#
#
# .iloc: locates by numeric index

# %%
p = movies_df.loc['Prometheus']
p
# Out:
# rank                                                           2
# genre                                   Adventure,Mystery,Sci-Fi
# description    Following clues to the origin of mankind, a te...
# director                                            Ridley Scott
# actors         Noomi Rapace, Logan Marshall-Green, Michael Fa...
# year                                                        2012
# runtime                                                      124
# rating                                                         7
# votes                                                     485820
# revenue                                                   126.46
# metascore                                                     65
# Name: Prometheus, dtype: object

# %%
p_iloc = movies_df.iloc[1]
p_iloc
# Out:
# rank                                                           2
# genre                                   Adventure,Mystery,Sci-Fi
# description    Following clues to the origin of mankind, a te...
# director                                            Ridley Scott
# actors         Noomi Rapace, Logan Marshall-Green, Michael Fa...
# year                                                        2012
# runtime                                                      124
# rating                                                         7
# votes                                                     485820
# revenue                                                   126.46
# metascore                                                     65
# Name: Prometheus, dtype: object

# %% [markdown]
# ####Conditional Selection

# %%
cond = (movies_df['director'] == 'Ridley Scott')
cond.head(1000)
# Out:
# Title
# Guardians of the Galaxy    False
# Prometheus                  True
# Split                      False
# Sing                       False
# Suicide Squad              False
#                            ...
# Secret in Their Eyes       False
# Hostel: Part II            False
# Step Up 2: The Streets     False
# Search Party               False
# Nine Lives                 False
# Name: director, Length: 1000, dtype: bool

# %%
movies_df[cond]
# Out:
#                         rank                     genre  ... revenue metascore
# Title                                                   ...
# Prometheus                 2  Adventure,Mystery,Sci-Fi  ...  126.46      65.0
# The Martian              103    Adventure,Drama,Sci-Fi  ...  228.43      80.0
# Robin Hood               388    Action,Adventure,Drama  ...  105.22      53.0
# American Gangster        471     Biography,Crime,Drama  ...  130.13      76.0
# Exodus: Gods and Kings   517    Action,Adventure,Drama  ...   65.01      52.0
# The Counselor            522      Crime,Drama,Thriller  ...   16.97      48.0
# A Good Year              531      Comedy,Drama,Romance  ...    7.46      47.0
# Body of Lies             738      Action,Drama,Romance  ...   39.38      57.0
#
# [8 rows x 11 columns]

# %%
#print all the movies whose rating is greater than 8.0
cond = (movies_df['rating'] > 8)
cond.head()
# Out:
# Title
# Guardians of the Galaxy     True
# Prometheus                 False
# Split                      False
# Sing                       False
# Suicide Squad              False
# Name: rating, dtype: bool

# %%
#movies whose rating is greater than 8.0
movies_df[cond]
# Out:
#                                               rank  ...  metascore
# Title                                               ...
# Guardians of the Galaxy                          1  ...  76.000000
# La La Land                                       7  ...  93.000000
# Hacksaw Ridge                                   17  ...  71.000000
# Lion                                            19  ...  69.000000
# Bahubali: The Beginning                         27  ...  58.985043
# Interstellar                                    37  ...  74.000000
# Star Wars: Episode VII - The Force Awakens      51  ...  81.000000
# The Dark Knight                                 55  ...  82.000000
# The Prestige                                    65  ...  66.000000
# Mad Max: Fury Road                              68  ...  90.000000
# Zootopia                                        75  ...  78.000000
# The Avengers                                    77  ...  69.000000
# Inglourious Basterds                            78  ...  69.000000
# Inception                                       81  ...  74.000000
# The Wolf of Wall Street                         83  ...  75.000000
# Gone Girl                                       84  ...  79.000000
# Prisoners                                       91  ...  74.000000
# The Help                                        93  ...  62.000000
# Kimi no na wa                                   97  ...  79.000000
# The Departed                                   100  ...  85.000000
# 12 Years a Slave                               112  ...  96.000000
# Harry Potter and the Deathly Hallows: Part 2   115  ...  87.000000
# Dangal                                         118  ...  58.985043
# The Dark Knight Rises                          125  ...  78.000000
# Whiplash                                       134  ...  88.000000
# No Country for Old Men                         137  ...  91.000000
# Shutter Island                                 139  ...  63.000000
# Room                                           144  ...  86.000000
# Django Unchained                               145  ...  81.000000
# Ah-ga-ssi                                      146  ...  84.000000
# Twin Peaks: The Missing Pieces                 155  ...  58.985043
# Spotlight                                      193  ...  93.000000
# Warrior                                        195  ...  71.000000
# Into the Wild                                  198  ...  73.000000
# The Imitation Game                             199  ...  73.000000
# Pan's Labyrinth                                231  ...  98.000000
# The Grand Budapest Hotel                       239  ...  88.000000
# Inside Out                                     242  ...  94.000000
# The Intouchables                               250  ...  57.000000
# There Will Be Blood                            300  ...  92.000000
# Rush                                           335  ...  75.000000
# The Bourne Ultimatum                           428  ...  85.000000
# 3 Idiots                                       431  ...  67.000000
# Jagten                                         456  ...  76.000000
# The Lives of Others                            477  ...  89.000000
# Paint It Black                                 479  ...  71.000000
# Up                                             500  ...  88.000000
# Mommy                                          609  ...  74.000000
# WALL·E                                         635  ...  58.985043
# Relatos salvajes                               642  ...  77.000000
# Gran Torino                                    646  ...  58.985043
# Toy Story 3                                    689  ...  92.000000
# Hachi: A Dog's Tale                            696  ...  61.000000
# Incendies                                      714  ...  80.000000
# El secreto de sus ojos                         743  ...  80.000000
# PK                                             766  ...  51.000000
# How to Train Your Dragon                       773  ...  74.000000
# Koe no katachi                                 862  ...  80.000000
# Taare Zameen Par                               992  ...  42.000000
#
# [59 rows x 11 columns]

# %%
#movies directed by Christopher Column and movies with ratings > 8.0
movies_df[(movies_df['director'] == 'Christopher Nolan')| cond]
# Out:
#                                               rank  ...  metascore
# Title                                               ...
# Guardians of the Galaxy                          1  ...  76.000000
# La La Land                                       7  ...  93.000000
# Hacksaw Ridge                                   17  ...  71.000000
# Lion                                            19  ...  69.000000
# Bahubali: The Beginning                         27  ...  58.985043
# Interstellar                                    37  ...  74.000000
# Star Wars: Episode VII - The Force Awakens      51  ...  81.000000
# The Dark Knight                                 55  ...  82.000000
# The Prestige                                    65  ...  66.000000
# Mad Max: Fury Road                              68  ...  90.000000
# Zootopia                                        75  ...  78.000000
# The Avengers                                    77  ...  69.000000
# Inglourious Basterds                            78  ...  69.000000
# Inception                                       81  ...  74.000000
# The Wolf of Wall Street                         83  ...  75.000000
# Gone Girl                                       84  ...  79.000000
# Prisoners                                       91  ...  74.000000
# The Help                                        93  ...  62.000000
# Kimi no na wa                                   97  ...  79.000000
# The Departed                                   100  ...  85.000000
# 12 Years a Slave                               112  ...  96.000000
# Harry Potter and the Deathly Hallows: Part 2   115  ...  87.000000
# Dangal                                         118  ...  58.985043
# The Dark Knight Rises                          125  ...  78.000000
# Whiplash                                       134  ...  88.000000
# No Country for Old Men                         137  ...  91.000000
# Shutter Island                                 139  ...  63.000000
# Room                                           144  ...  86.000000
# Django Unchained                               145  ...  81.000000
# Ah-ga-ssi                                      146  ...  84.000000
# Twin Peaks: The Missing Pieces                 155  ...  58.985043
# Spotlight                                      193  ...  93.000000
# Warrior                                        195  ...  71.000000
# Into the Wild                                  198  ...  73.000000
# The Imitation Game                             199  ...  73.000000
# Pan's Labyrinth                                231  ...  98.000000
# The Grand Budapest Hotel                       239  ...  88.000000
# Inside Out                                     242  ...  94.000000
# The Intouchables                               250  ...  57.000000
# There Will Be Blood                            300  ...  92.000000
# Rush                                           335  ...  75.000000
# The Bourne Ultimatum                           428  ...  85.000000
# 3 Idiots                                       431  ...  67.000000
# Jagten                                         456  ...  76.000000
# The Lives of Others                            477  ...  89.000000
# Paint It Black                                 479  ...  71.000000
# Up                                             500  ...  88.000000
# Mommy                                          609  ...  74.000000
# WALL·E                                         635  ...  58.985043
# Relatos salvajes                               642  ...  77.000000
# Gran Torino                                    646  ...  58.985043
# Toy Story 3                                    689  ...  92.000000
# Hachi: A Dog's Tale                            696  ...  61.000000
# Incendies                                      714  ...  80.000000
# El secreto de sus ojos                         743  ...  80.000000
# PK                                             766  ...  51.000000
# How to Train Your Dragon                       773  ...  74.000000
# Koe no katachi                                 862  ...  80.000000
# Taare Zameen Par                               992  ...  42.000000
#
# [59 rows x 11 columns]

# %%
#isin()
movies_df[movies_df['director'].isin(['Ridley Scott','Christopher Nolan'])]
# Out:
#                         rank                     genre  ... revenue metascore
# Title                                                   ...
# Prometheus                 2  Adventure,Mystery,Sci-Fi  ...  126.46      65.0
# Interstellar              37    Adventure,Drama,Sci-Fi  ...  187.99      74.0
# The Dark Knight           55        Action,Crime,Drama  ...  533.32      82.0
# The Prestige              65      Drama,Mystery,Sci-Fi  ...   53.08      66.0
# Inception                 81   Action,Adventure,Sci-Fi  ...  292.57      74.0
# The Martian              103    Adventure,Drama,Sci-Fi  ...  228.43      80.0
# The Dark Knight Rises    125           Action,Thriller  ...  448.13      78.0
# Robin Hood               388    Action,Adventure,Drama  ...  105.22      53.0
# American Gangster        471     Biography,Crime,Drama  ...  130.13      76.0
# Exodus: Gods and Kings   517    Action,Adventure,Drama  ...   65.01      52.0
# The Counselor            522      Crime,Drama,Thriller  ...   16.97      48.0
# A Good Year              531      Comedy,Drama,Romance  ...    7.46      47.0
# Body of Lies             738      Action,Drama,Romance  ...   39.38      57.0
#
# [13 rows x 11 columns]

# %% [markdown]
# #Task:
#
# 1. print all the movies that are released between the year 2005 and 2010
# 2. whose rating is more than 8.0
# 3. which made 25th percentile in revenue. (hint: use quantile(.25) to calculate the percentile.)

# %%
movies_df[(movies_df['year']>=2005) & (movies_df['year']<=2010) & (movies_df['rating']>8.0) & (movies_df['revenue']<movies_df['revenue'].quantile(0.25))]
# Out:
#                      rank               genre  ... revenue metascore
# Title                                          ...
# 3 Idiots              431        Comedy,Drama  ...    6.52      67.0
# The Lives of Others   477      Drama,Thriller  ...   11.28      89.0
# Incendies             714   Drama,Mystery,War  ...    6.86      80.0
# Taare Zameen Par      992  Drama,Family,Music  ...    1.20      42.0
#
# [4 rows x 11 columns]

# %%
def rating_fun(x):
  if(x >= 8.0):
    return "Good Movie"
  else:
    return "Bad Movie"

# %%
movies_df['user_review_column'] = movies_df['rating'].apply(rating_fun)
movies_df.head()
# Out:
#                          rank  ... user_review_column
# Title                          ...
# Guardians of the Galaxy     1  ...         Good Movie
# Prometheus                  2  ...          Bad Movie
# Split                       3  ...          Bad Movie
# Sing                        4  ...          Bad Movie
# Suicide Squad               5  ...          Bad Movie
#
# [5 rows x 12 columns]

# %% [markdown]
# ####Data Visulaization using Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams.update({'font.size':20, 'figure.figsize':(10,8)})

# %%
movies_df.plot(kind='scatter', x = 'rating', y = 'revenue', title='Revenue v/s Rating');

# %%
movies_df['rating'].plot(kind='hist',title='Rating');

# %%
movies_df['rating'].plot(kind='box',title='Rating');

# %%
movies_df.boxplot(column='revenue',by= 'user_review_column');
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
